# %% [markdown]
# # Spotify Song Popularity Predictor and Genre Recommendation System

# %% [markdown]
# #### Go with THIS flow
#
# 5. Recommendation system
#
# Content-based filtering and/or Collaborative filtering
#
# Song recommender based on features of a song that is input by the user
#
# Return playlist of 10-20 similar song s

# %%
# !pip install spotipy

# %%
import pandas as pd
import numpy as np
import random
from scipy import sparse
from sklearn.metrics.pairwise import pairwise_distances, cosine_distances, cosine_similarity
from sklearn.preprocessing import MinMaxScaler
from datetime import datetime

# %matplotlib inline

# %% [markdown]
# ## 5. Song Recommender Model

# %%
df_recommender = pd.read_csv("../datasets/data_recommender.csv")
df_recommender.head()
# Out:
#    acousticness                    artists  danceability  energy  explicit  \
# 0      0.991000            ['Mamie Smith']         0.598   0.224         0
# 1      0.643000  ["Screamin' Jay Hawkins"]         0.852   0.517         0
# 2      0.993000            ['Mamie Smith']         0.647   0.186         0
# 3      0.000173        ['Oscar Velazquez']         0.730   0.798         0
# 4      0.295000                   ['Mixe']         0.704   0.707         1
#
#    instrumentalness  key  liveness  loudness  mode  \
# 0          0.000522    5    0.3790   -12.628     0
# 1          0.026400    5    0.0809    -7.261     0
# 2          0.000018    0    0.5190   -12.098     1
# 3          0.801000    2    0.1280    -7.311     1
# 4          0.000246   10    0.4020    -6.036     0
#
#                                                 name  popularity  speechiness  \
# 0                           Keep A Song In Your Soul        0.12       0.0936
# 1                               I Put A Spell On You        0.07       0.0534
# 2                                       Golfing Papa        0.04       0.1740
# 3  True House Music - Xavier Santos & Carlos Gomi...        0.17       0.0425
# 4                                          Xuniverxe        0.02       0.0768
#
#      tempo  valence  year  duration_mins
# 0  149.976   0.6340  1920           2.81
# 1   86.889   0.9500  1920           2.50
# 2   97.600   0.6890  1920           2.73
# 3  127.997   0.0422  1920           7.03
# 4  122.076   0.2990  1920           2.75

# %%
df_recommender.shape
# Out:
# (159477, 17)

# %% [markdown]
# ### 5.1 Preprocessing

# %% [markdown]
# Since the dataframe still contains almost 160,000 rows, it's not feasible to create a recommender with all those songs. Instead, we'll be taking a subset of the dataframe with songs from 1990 onwards. In addition, all duplicated song versions from the SAME artist will be dropped, keeping only the version with the highest popularity.
#
# We will still keep the same song sung by different artist to ensure that songs with identical titles are not deleted.

# %%
df_recommender = df_recommender.sort_values('popularity', ascending=False)
df_recommender.drop_duplicates(subset=['artists', 'name'], keep='first', inplace=True)

# %%
df_recommender_from_1990 = df_recommender[df_recommender.year >= 2000]
df_recommender_from_1990.describe()['year']
# Out:
# count    36524.000000
# mean      2011.930265
# std          6.119169
# min       2000.000000
# 25%       2007.000000
# 50%       2013.000000
# 75%       2017.000000
# max       2021.000000
# Name: year, dtype: float64

# %%
df_recommender_from_1990.shape
# Out:
# (36524, 17)

# %%
df_recommender_from_1990[df_recommender_from_1990.name.duplicated()]['name'].value_counts().head(50)
# Out:
# 2000 Years                                                     51
# Happy New Year                                                 21
# 7 Years                                                        18
# Stay                                                           16
# New Year                                                       16
# Year 2000                                                      15
# Have Yourself a Merry Little Christmas                         15
# 2000 Light Years from Home                                     12
# It's the Most Wonderful Time of the Year                       12
# Home                                                           12
# Neujahrsgruß / New Year's Address / Allocution du Nouvel An    12
# Hold On                                                        11
# 2000 Years Ago                                                 10
# Winter Wonderland                                              10
# A Thousand Years                                               10
# Intro                                                           9
# Happy New Year 2021                                             9
# Radetzky-Marsch, Op. 228                                        9
# That Time of Year                                               8
# Santa Baby                                                      8
# Beautiful                                                       8
# Believe                                                         8
# You                                                             8
# Smile                                                           8
# Background for 2021                                             8
# Forever                                                         8
# Daylight                                                        7
# Trouble                                                         7
# Alone                                                           7
# Monster                                                         7
# Wake Up                                                         7
# Save Me                                                         7
# The Year 2000                                                   7
# Broken                                                          7
# Ghost                                                           7
# In the Year 2000                                                7
# Without You                                                     7
# Heaven                                                          7
# Breathe                                                         7
# New Year Eve 2019                                               6
# Gone                                                            6
# Closer                                                          6
# Baby                                                            6
# Alive                                                           6
# Runaway                                                         6
# Love Me                                                         6
# Years                                                           6
# 2021                                                            6
# 2000 Light Years From Home                                      6
# Hurricane                                                       6
# Name: name, dtype: int64

# %%
drop_features = ['explicit', 'key', 'mode', 'year', 'duration_mins', 'artists']
scale_features = ['loudness', 'tempo']
features = ['acousticness', 'danceability', 'energy', 'instrumentalness', 'liveness', 'speechiness', 'valence']

# %%
df_recommender_from_1990 = df_recommender_from_1990.drop(drop_features, axis=1)
df_recommender_from_1990
# Out:
#         acousticness  danceability  energy  instrumentalness  liveness  \
# 18818       0.721000         0.585   0.436          0.000013    0.1050
# 18639       0.221000         0.700   0.722          0.000000    0.2720
# 18642       0.468000         0.737   0.802          0.000000    0.0931
# 18734       0.212000         0.863   0.666          0.000493    0.1030
# 18656       0.401000         0.731   0.573          0.000052    0.1130
# ...              ...           ...     ...               ...       ...
# 113145      0.000951         0.772   0.546          0.924000    0.1020
# 113158      0.007550         0.775   0.616          0.881000    0.1130
# 113160      0.076500         0.626   0.913          0.627000    0.0908
# 113154      0.001810         0.617   0.674          0.905000    0.1040
# 113151      0.042000         0.310   0.668          0.818000    0.0731
#
#         loudness                                        name  popularity  \
# 18818     -8.761                             drivers license        1.00
# 18639     -3.558                      Mood (feat. iann dior)        0.96
# 18642     -4.771                                   positions        0.96
# 18734     -4.158                                     BICHOTA        0.95
# 18656    -10.059                                      DÁKITI        0.95
# ...          ...                                         ...         ...
# 113145    -7.413                                     Force A        0.00
# 113158    -8.415                        Saff - Tex-Rec Remix        0.00
# 113160    -9.882                               Jump the Next        0.00
# 113154    -9.088  Krim - Marco Asoleda vs Roman Kramer Remix        0.00
# 113151    -7.058                               London Groove        0.00
#
#         speechiness    tempo  valence
# 18818        0.0601  143.874   0.1320
# 18639        0.0369   90.989   0.7560
# 18642        0.0878  144.015   0.6820
# 18734        0.1520  163.908   0.8380
# 18656        0.0544  109.928   0.1450
# ...             ...      ...      ...
# 113145       0.0543  124.000   0.0862
# 113158       0.0579  124.989   0.0350
# 113160       0.0370   95.995   0.4820
# 113154       0.0541  124.996   0.1530
# 113151       0.0687   77.977   0.1050
#
# [36524 rows x 11 columns]

# %%
def min_max_scale(X, range=(0, 1)):
    mi, ma = range
    X_std = (X - X.min()) / (X.max() - X.min())
    X_scaled = X_std * (ma - mi) + mi
    return X_scaled

# %%
for feature in scale_features: 
    df_recommender_from_1990[feature] = min_max_scale(df_recommender_from_1990[feature])
    print(df_recommender_from_1990[feature].describe())
# Out:
# count    36524.000000
# mean         0.802669
# std          0.078647
# min          0.000000
# 25%          0.777480
# 50%          0.821710
# 75%          0.852051
# max          1.000000
# Name: loudness, dtype: float64
# count    36524.000000
# mean         0.553456
# std          0.127978
# min          0.000000
# 25%          0.451074
# 50%          0.563193
# 75%          0.627113
# max          1.000000
# Name: tempo, dtype: float64

# %%
df_recommender_from_1990 = df_recommender_from_1990.set_index('name', drop=True)
df_recommender_from_1990.head()
# Out:
#                         acousticness  danceability  energy  instrumentalness  \
# name
# drivers license                0.721         0.585   0.436          0.000013
# Mood (feat. iann dior)         0.221         0.700   0.722          0.000000
# positions                      0.468         0.737   0.802          0.000000
# BICHOTA                        0.212         0.863   0.666          0.000493
# DÁKITI                         0.401         0.731   0.573          0.000052
#
#                         liveness  loudness  popularity  speechiness     tempo  \
# name
# drivers license           0.1050  0.789966        1.00       0.0601  0.648215
# Mood (feat. iann dior)    0.2720  0.880072        0.96       0.0369  0.409945
# positions                 0.0931  0.859065        0.96       0.0878  0.648851
# BICHOTA                   0.1030  0.869681        0.95       0.1520  0.738477
# DÁKITI                    0.1130  0.767487        0.95       0.0544  0.495274
#
#                         valence
# name
# drivers license           0.132
# Mood (feat. iann dior)    0.756
# positions                 0.682
# BICHOTA                   0.838
# DÁKITI                    0.145

# %% [markdown]
# ##### Genres

# %%
df_genres = pd.read_csv("../datasets/data_by_genres_cleaned.csv", index_col=['genres'])
df_genres.head()
# Out:
#                         acousticness  danceability    energy  \
# genres
# 21st century classical      0.754600      0.284100  0.159580
# 432hz                       0.485515      0.312000  0.391678
# 8-bit                       0.028900      0.673000  0.950000
# []                          0.535793      0.546937  0.485430
# a cappella                  0.694276      0.516172  0.330533
#
#                         instrumentalness  liveness   loudness  speechiness  \
# genres
# 21st century classical          0.484374  0.168580 -22.153400     0.062060
# 432hz                           0.477250  0.265940 -18.131267     0.071717
# 8-bit                           0.630000  0.069000  -7.899000     0.292000
# []                              0.278442  0.220970 -11.624754     0.101511
# a cappella                      0.036080  0.222983 -12.656547     0.083627
#
#                              tempo   valence  popularity  key  mode  \
# genres
# 21st century classical   91.351000  0.143380    0.066000    4     1
# 432hz                   118.900933  0.236483    0.412000   11     1
# 8-bit                   192.816000  0.997000    0.000000    5     1
# []                      116.068980  0.486361    0.123508    7     1
# a cappella              105.506031  0.454077    0.390862    7     1
#
#                         duration_mins
# genres
# 21st century classical           5.88
# 432hz                           17.46
# 8-bit                            2.22
# []                               4.16
# a cappella                       3.36

# %%
df_genres.drop(['key', 'mode', 'duration_mins'], axis=1, inplace=True)

# %%
df_genres.head()
# Out:
#                         acousticness  danceability    energy  \
# genres
# 21st century classical      0.754600      0.284100  0.159580
# 432hz                       0.485515      0.312000  0.391678
# 8-bit                       0.028900      0.673000  0.950000
# []                          0.535793      0.546937  0.485430
# a cappella                  0.694276      0.516172  0.330533
#
#                         instrumentalness  liveness   loudness  speechiness  \
# genres
# 21st century classical          0.484374  0.168580 -22.153400     0.062060
# 432hz                           0.477250  0.265940 -18.131267     0.071717
# 8-bit                           0.630000  0.069000  -7.899000     0.292000
# []                              0.278442  0.220970 -11.624754     0.101511
# a cappella                      0.036080  0.222983 -12.656547     0.083627
#
#                              tempo   valence  popularity
# genres
# 21st century classical   91.351000  0.143380    0.066000
# 432hz                   118.900933  0.236483    0.412000
# 8-bit                   192.816000  0.997000    0.000000
# []                      116.068980  0.486361    0.123508
# a cappella              105.506031  0.454077    0.390862

# %% [markdown]
# Re-organising columns

# %%
column_order = list(df_recommender_from_1990.columns)
df_genres = df_genres[column_order]
df_genres.head()
# Out:
#                         acousticness  danceability    energy  \
# genres
# 21st century classical      0.754600      0.284100  0.159580
# 432hz                       0.485515      0.312000  0.391678
# 8-bit                       0.028900      0.673000  0.950000
# []                          0.535793      0.546937  0.485430
# a cappella                  0.694276      0.516172  0.330533
#
#                         instrumentalness  liveness   loudness  popularity  \
# genres
# 21st century classical          0.484374  0.168580 -22.153400    0.066000
# 432hz                           0.477250  0.265940 -18.131267    0.412000
# 8-bit                           0.630000  0.069000  -7.899000    0.000000
# []                              0.278442  0.220970 -11.624754    0.123508
# a cappella                      0.036080  0.222983 -12.656547    0.390862
#
#                         speechiness       tempo   valence
# genres
# 21st century classical     0.062060   91.351000  0.143380
# 432hz                      0.071717  118.900933  0.236483
# 8-bit                      0.292000  192.816000  0.997000
# []                         0.101511  116.068980  0.486361
# a cappella                 0.083627  105.506031  0.454077

# %%
df_genres.sort_values('popularity', ascending=False).head(50)
# Out:
#                           acousticness  danceability    energy  \
# genres
# chinese electropop            0.002570      0.660000  0.787000
# korean mask singer            0.238000      0.658000  0.749000
# yaoi                          0.006550      0.603000  0.964000
# dutch rap pop                 0.216000      0.767000  0.643000
# rochester mn indie            0.034700      0.655000  0.487000
# dong-yo                       0.259000      0.829000  0.886000
# afroswing                     0.171333      0.758333  0.512000
# j-rap                         0.096100      0.648000  0.904000
# estonian pop                  0.285000      0.458000  0.696000
# irish pop                     0.308600      0.474750  0.513625
# musical advocacy              0.176500      0.563500  0.544500
# alberta hip hop               0.330000      0.885000  0.685000
# channel islands indie         0.147000      0.625000  0.763000
# newcastle nsw indie           0.003920      0.498000  0.810000
# instrumental grime            0.341453      0.743933  0.631533
# guatemalan pop                0.622000      0.591000  0.672000
# rock chapin                   0.622000      0.591000  0.672000
# swedish tropical house        0.022500      0.632000  0.575000
# london rap                    0.142567      0.698333  0.500000
# japanese teen pop             0.014870      0.607667  0.899333
# indonesian r&b                0.251500      0.616000  0.510000
# chinese hip hop               0.359000      0.409000  0.678000
# dembow                        0.167690      0.817400  0.723000
# scam rap                      0.184608      0.829222  0.700667
# irish indie                   0.988000      0.521000  0.088900
# future house                  0.005210      0.609000  0.885000
# finnish alternative rock      0.000109      0.600000  0.796000
# german pop rock               0.299750      0.618400  0.551400
# mexican pop punk              0.009040      0.488000  0.897000
# scandinavian r&b              0.388000      0.705000  0.433000
# punk rock mexicano            0.009040      0.488000  0.897000
# swedish soul                  0.388000      0.705000  0.433000
# emo mexicano                  0.009040      0.488000  0.897000
# virgin islands reggae         0.316000      0.508500  0.674000
# uk contemporary r&b           0.156367      0.672518  0.718449
# viral rap                     0.151399      0.784453  0.650716
# baltimore hip hop             0.349000      0.762000  0.383000
# south african house           0.094500      0.781000  0.721000
# hawaiian hip hop              0.421008      0.725192  0.506346
# j-pixie                       0.195848      0.517333  0.722333
# bergen indie                  0.382600      0.720000  0.608111
# brooklyn drill                0.276560      0.726055  0.666046
# cambridgeshire indie          0.795000      0.358000  0.546000
# lo-fi house                   0.385450      0.764500  0.275000
# german underground rap        0.065000      0.859000  0.792000
# alaska indie                  0.047300      0.810000  0.353000
# indie rockism                 0.012124      0.589000  0.806750
# asmr                          0.016903      0.145667  0.683000
# indonesian hip hop            0.298976      0.674000  0.588500
# lo-fi chill                   0.676679      0.705395  0.256214
#
#                           instrumentalness  liveness   loudness  popularity  \
# genres
# chinese electropop            0.000000e+00  0.323000  -4.592000    0.790000
# korean mask singer            2.030000e-06  0.272000  -2.967000    0.780000
# yaoi                          3.040000e-06  0.143000  -2.886000    0.770000
# dutch rap pop                 1.040000e-04  0.080600  -5.225000    0.770000
# rochester mn indie            8.970000e-01  0.271000  -7.988000    0.760000
# dong-yo                       0.000000e+00  0.055900  -1.746000    0.760000
# afroswing                     3.273333e-05  0.101033  -7.562667    0.753333
# j-rap                         2.070000e-06  0.062900  -4.565000    0.750000
# estonian pop                  0.000000e+00  0.123000  -4.742000    0.750000
# irish pop                     2.429470e-02  0.146075  -8.183875    0.746250
# musical advocacy              1.665000e-05  0.086850 -11.095500    0.745000
# alberta hip hop               0.000000e+00  0.148000  -6.429000    0.745000
# channel islands indie         1.060000e-02  0.214000  -4.997000    0.740000
# newcastle nsw indie           7.170000e-03  0.063500  -4.065000    0.740000
# instrumental grime            1.090613e-02  0.098587  -6.415400    0.731333
# guatemalan pop                0.000000e+00  0.112000  -3.515000    0.730000
# rock chapin                   0.000000e+00  0.112000  -3.515000    0.730000
# swedish tropical house        1.810000e-06  0.104000  -6.478000    0.730000
# london rap                    0.000000e+00  0.093700  -7.315667    0.723333
# japanese teen pop             6.126667e-06  0.193833  -3.653667    0.716667
# indonesian r&b                0.000000e+00  0.087400  -7.639500    0.710000
# chinese hip hop               4.760000e-06  0.167000  -7.731000    0.710000
# dembow                        1.166238e-03  0.104500  -5.758000    0.701000
# scam rap                      3.136306e-05  0.100042  -4.523389    0.700278
# irish indie                   1.820000e-01  0.096500 -19.457000    0.700000
# future house                  1.150000e-05  0.336000  -5.469000    0.690000
# finnish alternative rock      5.200000e-05  0.484000  -4.481000    0.690000
# german pop rock               2.804000e-02  0.126920  -8.942400    0.690000
# mexican pop punk              5.910000e-05  0.311000  -6.503000    0.690000
# scandinavian r&b              1.340000e-01  0.084100  -9.706000    0.690000
# punk rock mexicano            5.910000e-05  0.311000  -6.503000    0.690000
# swedish soul                  1.340000e-01  0.084100  -9.706000    0.690000
# emo mexicano                  5.910000e-05  0.311000  -6.503000    0.690000
# virgin islands reggae         0.000000e+00  0.047150  -5.702500    0.685000
# uk contemporary r&b           2.347418e-02  0.168724  -6.320025    0.683098
# viral rap                     1.987793e-02  0.173575  -7.551880    0.681747
# baltimore hip hop             0.000000e+00  0.127000 -10.098000    0.680000
# south african house           3.910000e-01  0.104000  -9.133000    0.680000
# hawaiian hip hop              5.904538e-05  0.117746  -7.385192    0.679615
# j-pixie                       3.796667e-04  0.107183  -3.300167    0.678333
# bergen indie                  1.000874e-01  0.134511  -8.228167    0.673333
# brooklyn drill                3.788707e-04  0.152607  -6.020790    0.672579
# cambridgeshire indie          5.860000e-02  0.111000  -8.927000    0.670000
# lo-fi house                   9.575000e-01  0.168100 -11.839000    0.670000
# german underground rap        0.000000e+00  0.300000  -4.007000    0.670000
# alaska indie                  1.040000e-04  0.082000  -9.536000    0.670000
# indie rockism                 1.562500e-07  0.146250  -4.276125    0.668750
# asmr                          8.733333e-01  0.438333 -24.421000    0.666667
# indonesian hip hop            9.185500e-05  0.120900  -7.966333    0.665000
# lo-fi chill                   1.823289e-01  0.164142 -14.438052    0.663838
#
#                           speechiness       tempo   valence
# genres
# chinese electropop           0.032000  142.018000  0.199000
# korean mask singer           0.063400  128.909000  0.442000
# yaoi                         0.048700  135.028000  0.796000
# dutch rap pop                0.101000  169.990000  0.536000
# rochester mn indie           0.033000  139.914000  0.045400
# dong-yo                      0.112000  115.056000  0.777000
# afroswing                    0.211000  102.061000  0.480333
# j-rap                        0.078600  121.994000  0.728000
# estonian pop                 0.040200  174.141000  0.418000
# irish pop                    0.057700  111.043375  0.265238
# musical advocacy             0.039900   93.996000  0.320500
# alberta hip hop              0.062700   99.954000  0.937000
# channel islands indie        0.129000   88.753000  0.721000
# newcastle nsw indie          0.026300   79.935000  0.594000
# instrumental grime           0.153467  124.013600  0.594000
# guatemalan pop               0.037500  139.939000  0.267000
# rock chapin                  0.037500  139.939000  0.267000
# swedish tropical house       0.029000   90.037000  0.188000
# london rap                   0.198000  111.078667  0.502333
# japanese teen pop            0.051467  127.378667  0.742333
# indonesian r&b               0.165450  158.781500  0.300500
# chinese hip hop              0.087800   89.968000  0.168000
# dembow                       0.148310  111.267600  0.741700
# scam rap                     0.282722  121.637139  0.465056
# irish indie                  0.050700  115.430000  0.047900
# future house                 0.064200  124.959000  0.760000
# finnish alternative rock     0.027500  105.991000  0.750000
# german pop rock              0.032500  115.863200  0.508800
# mexican pop punk             0.114000  172.054000  0.814000
# scandinavian r&b             0.204000  168.006000  0.602000
# punk rock mexicano           0.114000  172.054000  0.814000
# swedish soul                 0.204000  168.006000  0.602000
# emo mexicano                 0.114000  172.054000  0.814000
# virgin islands reggae        0.066700  120.170500  0.562500
# uk contemporary r&b          0.080335  111.786327  0.546245
# viral rap                    0.207384  125.355556  0.549317
# baltimore hip hop            0.202000   92.947000  0.440000
# south african house          0.051400  123.011000  0.849000
# hawaiian hip hop             0.198262   99.254462  0.346231
# j-pixie                      0.106500  163.837667  0.338333
# bergen indie                 0.038806  142.795556  0.839778
# brooklyn drill               0.253270  119.130509  0.584669
# cambridgeshire indie         0.029600  106.489000  0.264000
# lo-fi house                  0.091350   83.185000  0.383000
# german underground rap       0.141000  103.201000  0.766000
# alaska indie                 0.043700  124.991000  0.731000
# indie rockism                0.038650  118.271375  0.648750
# asmr                         0.095133   98.668667  0.024433
# indonesian hip hop           0.151900  102.002333  0.259500
# lo-fi chill                  0.186016  115.525856  0.403512

# %% [markdown]
# ### 5.2 Cosine Similarity

# %%
sim_matrix = cosine_similarity(df_recommender_from_1990)
songs_sim = pd.DataFrame(sim_matrix, columns=df_recommender_from_1990.index, index=df_recommender_from_1990.index)
songs_sim
# Out:
# name                                        drivers license  \
# name
# drivers license                                    1.000000
# Mood (feat. iann dior)                             0.878134
# positions                                          0.931726
# BICHOTA                                            0.884042
# DÁKITI                                             0.972977
# ...                                                     ...
# Force A                                            0.587354
# Saff - Tex-Rec Remix                               0.596418
# Jump the Next                                      0.619886
# Krim - Marco Asoleda vs Roman Kramer Remix         0.584717
# London Groove                                      0.557085
#
# name                                        Mood (feat. iann dior)  positions  \
# name
# drivers license                                           0.878134   0.931726
# Mood (feat. iann dior)                                    1.000000   0.979286
# positions                                                 0.979286   1.000000
# BICHOTA                                                   0.978888   0.983522
# DÁKITI                                                    0.932400   0.958440
# ...                                                            ...        ...
# Force A                                                   0.630964   0.649252
# Saff - Tex-Rec Remix                                      0.634664   0.656206
# Jump the Next                                             0.767626   0.775245
# Krim - Marco Asoleda vs Roman Kramer Remix                0.648837   0.667680
# London Groove                                             0.622433   0.634459
#
# name                                         BICHOTA    DÁKITI  WITHOUT YOU  \
# name
# drivers license                             0.884042  0.972977     0.927943
# Mood (feat. iann dior)                      0.978888  0.932400     0.978757
# positions                                   0.983522  0.958440     0.970867
# BICHOTA                                     1.000000  0.929166     0.972536
# DÁKITI                                      0.929166  1.000000     0.967560
# ...                                              ...       ...          ...
# Force A                                     0.662556  0.651916     0.630802
# Saff - Tex-Rec Remix                        0.664010  0.664149     0.632017
# Jump the Next                               0.774183  0.697963     0.705198
# Krim - Marco Asoleda vs Roman Kramer Remix  0.673132  0.648148     0.629712
# London Groove                               0.618459  0.611313     0.592924
#
# name                                         Whoopty  Therefore I Am  \
# name
# drivers license                             0.892633        0.878563
# Mood (feat. iann dior)                      0.984882        0.963889
# positions                                   0.983919        0.953432
# BICHOTA                                     0.997247        0.974418
# DÁKITI                                      0.935282        0.924490
# ...                                              ...             ...
# Force A                                     0.643617        0.659899
# Saff - Tex-Rec Remix                        0.645269        0.653403
# Jump the Next                               0.755401        0.728794
# Krim - Marco Asoleda vs Roman Kramer Remix  0.656480        0.650489
# London Groove                               0.611269        0.593005
#
# name                                           34+35  LA NOCHE DE ANOCHE  ...  \
# name                                                                      ...
# drivers license                             0.922586            0.873750  ...
# Mood (feat. iann dior)                      0.983186            0.956811  ...
# positions                                   0.978052            0.944472  ...
# BICHOTA                                     0.978838            0.956691  ...
# DÁKITI                                      0.972974            0.951624  ...
# ...                                              ...                 ...  ...
# Force A                                     0.668728            0.670819  ...
# Saff - Tex-Rec Remix                        0.674663            0.678096  ...
# Jump the Next                               0.749580            0.741885  ...
# Krim - Marco Asoleda vs Roman Kramer Remix  0.669049            0.668164  ...
# London Groove                               0.621955            0.628130  ...
#
# name                                        Bionic Flame - Dark Room Alliance Obscure Rework  \
# name
# drivers license                                                                     0.578682
# Mood (feat. iann dior)                                                              0.608401
# positions                                                                           0.632146
# BICHOTA                                                                             0.641070
# DÁKITI                                                                              0.637899
# ...                                                                                      ...
# Force A                                                                             0.998053
# Saff - Tex-Rec Remix                                                                0.997342
# Jump the Next                                                                       0.912724
# Krim - Marco Asoleda vs Roman Kramer Remix                                          0.992481
# London Groove                                                                       0.952616
#
# name                                        Step Asidex  \
# name
# drivers license                                0.713137
# Mood (feat. iann dior)                         0.759808
# positions                                      0.797853
# BICHOTA                                        0.793654
# DÁKITI                                         0.755515
# ...                                                 ...
# Force A                                        0.943165
# Saff - Tex-Rec Remix                           0.944936
# Jump the Next                                  0.960216
# Krim - Marco Asoleda vs Roman Kramer Remix     0.944762
# London Groove                                  0.897184
#
# name                                        Carretta - David Carretta Remix  \
# name
# drivers license                                                    0.567673
# Mood (feat. iann dior)                                             0.729584
# positions                                                          0.734481
# BICHOTA                                                            0.755734
# DÁKITI                                                             0.639207
# ...                                                                     ...
# Force A                                                            0.930378
# Saff - Tex-Rec Remix                                               0.925464
# Jump the Next                                                      0.980555
# Krim - Marco Asoleda vs Roman Kramer Remix                         0.953340
# London Groove                                                      0.920085
#
# name                                        Coupe Drug  Tokio Beatz   Force A  \
# name
# drivers license                               0.608904     0.614280  0.587354
# Mood (feat. iann dior)                        0.723735     0.706965  0.630964
# positions                                     0.748842     0.707305  0.649252
# BICHOTA                                       0.766269     0.711927  0.662556
# DÁKITI                                        0.666303     0.696033  0.651916
# ...                                                ...          ...       ...
# Force A                                       0.929951     0.967260  1.000000
# Saff - Tex-Rec Remix                          0.931244     0.974596  0.998198
# Jump the Next                                 0.968289     0.953899  0.921331
# Krim - Marco Asoleda vs Roman Kramer Remix    0.957069     0.972954  0.991652
# London Groove                                 0.914701     0.939629  0.950804
#
# name                                        Saff - Tex-Rec Remix  \
# name
# drivers license                                         0.596418
# Mood (feat. iann dior)                                  0.634664
# positions                                               0.656206
# BICHOTA                                                 0.664010
# DÁKITI                                                  0.664149
# ...                                                          ...
# Force A                                                 0.998198
# Saff - Tex-Rec Remix                                    1.000000
# Jump the Next                                           0.925977
# Krim - Marco Asoleda vs Roman Kramer Remix              0.992119
# London Groove                                           0.952149
#
# name                                        Jump the Next  \
# name
# drivers license                                  0.619886
# Mood (feat. iann dior)                           0.767626
# positions                                        0.775245
# BICHOTA                                          0.774183
# DÁKITI                                           0.697963
# ...                                                   ...
# Force A                                          0.921331
# Saff - Tex-Rec Remix                             0.925977
# Jump the Next                                    1.000000
# Krim - Marco Asoleda vs Roman Kramer Remix       0.949535
# London Groove                                    0.933344
#
# name                                        Krim - Marco Asoleda vs Roman Kramer Remix  \
# name
# drivers license                                                               0.584717
# Mood (feat. iann dior)                                                        0.648837
# positions                                                                     0.667680
# BICHOTA                                                                       0.673132
# DÁKITI                                                                        0.648148
# ...                                                                                ...
# Force A                                                                       0.991652
# Saff - Tex-Rec Remix                                                          0.992119
# Jump the Next                                                                 0.949535
# Krim - Marco Asoleda vs Roman Kramer Remix                                    1.000000
# London Groove                                                                 0.975088
#
# name                                        London Groove
# name
# drivers license                                  0.557085
# Mood (feat. iann dior)                           0.622433
# positions                                        0.634459
# BICHOTA                                          0.618459
# DÁKITI                                           0.611313
# ...                                                   ...
# Force A                                          0.950804
# Saff - Tex-Rec Remix                             0.952149
# Jump the Next                                    0.933344
# Krim - Marco Asoleda vs Roman Kramer Remix       0.975088
# London Groove                                    1.000000
#
# [36524 rows x 36524 columns]

# %%
songs_sim['drivers license'].sort_values(ascending=False).head(20)
# Out:
# name
# drivers license                  1.000000
# you broke me first               0.995865
# The Scientist                    0.994393
# Hope                             0.993651
# Photograph                       0.993509
# Give Me Love                     0.992375
# If I Ain't Got You               0.992303
# Nikes                            0.991786
# If You Want Love                 0.991230
# ocean eyes                       0.991230
# Lose You To Love Me              0.991089
# Moral of the Story               0.990850
# Runaway                          0.990314
# Control                          0.990103
# I Won't Give Up                  0.989875
# Another Love                     0.989712
# Corduroy Dreams                  0.989556
# Hold On                          0.988616
# Get You The Moon (feat. Snøw)    0.988511
# Follow The Sun                   0.988474
# Name: drivers license, dtype: float64

# %% [markdown]
# #### Genre(s) To Recommend

# %%
genres_to_recommend = ['swedish tropical house', 'indie rockism' , 'lo-fi chill', 'rochester mn indie']

# %%
genre_choice = 'rochester mn indie'

# %% [markdown]
# Let's recommend songs with similar features to swedish tropical house

# %%
df_genre_recc = pd.concat([pd.DataFrame(df_genres.loc[genre_choice]).T, df_recommender_from_1990], axis=0)
df_genre_recc.head()
# Out:
#                         acousticness  danceability  energy  instrumentalness  \
# rochester mn indie            0.0347         0.655   0.487          0.897000
# drivers license               0.7210         0.585   0.436          0.000013
# Mood (feat. iann dior)        0.2210         0.700   0.722          0.000000
# positions                     0.4680         0.737   0.802          0.000000
# BICHOTA                       0.2120         0.863   0.666          0.000493
#
#                         liveness  loudness  popularity  speechiness  \
# rochester mn indie        0.2710 -7.988000        0.76       0.0330
# drivers license           0.1050  0.789966        1.00       0.0601
# Mood (feat. iann dior)    0.2720  0.880072        0.96       0.0369
# positions                 0.0931  0.859065        0.96       0.0878
# BICHOTA                   0.1030  0.869681        0.95       0.1520
#
#                              tempo  valence
# rochester mn indie      139.914000   0.0454
# drivers license           0.648215   0.1320
# Mood (feat. iann dior)    0.409945   0.7560
# positions                 0.648851   0.6820
# BICHOTA                   0.738477   0.8380

# %%
start_time = datetime.now()
print(f"Recommending {genre_choice} music...")
sim_matrix_genre = cosine_similarity(df_genre_recc)
songs_sim_genre = pd.DataFrame(sim_matrix_genre, columns=df_genre_recc.index, index=df_genre_recc.index)
songs_sim_genre

end_time = datetime.now()
print('Duration: {}'.format(end_time - start_time))
# Out:
# Recommending rochester mn indie music...
# Duration: 0:06:11.720545

# %%
df_songs_sim_genre = pd.DataFrame(sim_matrix_genre, columns=df_genre_recc.index, index=df_genre_recc.index)
df_songs_sim_genre
# Out:
#                                             rochester mn indie  \
# rochester mn indie                                    1.000000
# drivers license                                       0.346128
# Mood (feat. iann dior)                                0.196277
# positions                                             0.306634
# BICHOTA                                               0.342519
# ...                                                        ...
# Force A                                               0.315849
# Saff - Tex-Rec Remix                                  0.320175
# Jump the Next                                         0.244820
# Krim - Marco Asoleda vs Roman Kramer Remix            0.326477
# London Groove                                         0.219887
#
#                                             drivers license  \
# rochester mn indie                                 0.346128
# drivers license                                    1.000000
# Mood (feat. iann dior)                             0.878134
# positions                                          0.931726
# BICHOTA                                            0.884042
# ...                                                     ...
# Force A                                            0.587354
# Saff - Tex-Rec Remix                               0.596418
# Jump the Next                                      0.619886
# Krim - Marco Asoleda vs Roman Kramer Remix         0.584717
# London Groove                                      0.557085
#
#                                             Mood (feat. iann dior)  positions  \
# rochester mn indie                                        0.196277   0.306634
# drivers license                                           0.878134   0.931726
# Mood (feat. iann dior)                                    1.000000   0.979286
# positions                                                 0.979286   1.000000
# BICHOTA                                                   0.978888   0.983522
# ...                                                            ...        ...
# Force A                                                   0.630964   0.649252
# Saff - Tex-Rec Remix                                      0.634664   0.656206
# Jump the Next                                             0.767626   0.775245
# Krim - Marco Asoleda vs Roman Kramer Remix                0.648837   0.667680
# London Groove                                             0.622433   0.634459
#
#                                              BICHOTA    DÁKITI  WITHOUT YOU  \
# rochester mn indie                          0.342519  0.276024     0.236306
# drivers license                             0.884042  0.972977     0.927943
# Mood (feat. iann dior)                      0.978888  0.932400     0.978757
# positions                                   0.983522  0.958440     0.970867
# BICHOTA                                     1.000000  0.929166     0.972536
# ...                                              ...       ...          ...
# Force A                                     0.662556  0.651916     0.630802
# Saff - Tex-Rec Remix                        0.664010  0.664149     0.632017
# Jump the Next                               0.774183  0.697963     0.705198
# Krim - Marco Asoleda vs Roman Kramer Remix  0.673132  0.648148     0.629712
# London Groove                               0.618459  0.611313     0.592924
#
#                                              Whoopty  Therefore I Am  \
# rochester mn indie                          0.321230        0.217008
# drivers license                             0.892633        0.878563
# Mood (feat. iann dior)                      0.984882        0.963889
# positions                                   0.983919        0.953432
# BICHOTA                                     0.997247        0.974418
# ...                                              ...             ...
# Force A                                     0.643617        0.659899
# Saff - Tex-Rec Remix                        0.645269        0.653403
# Jump the Next                               0.755401        0.728794
# Krim - Marco Asoleda vs Roman Kramer Remix  0.656480        0.650489
# London Groove                               0.611269        0.593005
#
#                                                34+35  ...  \
# rochester mn indie                          0.256247  ...
# drivers license                             0.922586  ...
# Mood (feat. iann dior)                      0.983186  ...
# positions                                   0.978052  ...
# BICHOTA                                     0.978838  ...
# ...                                              ...  ...
# Force A                                     0.668728  ...
# Saff - Tex-Rec Remix                        0.674663  ...
# Jump the Next                               0.749580  ...
# Krim - Marco Asoleda vs Roman Kramer Remix  0.669049  ...
# London Groove                               0.621955  ...
#
#                                             Bionic Flame - Dark Room Alliance Obscure Rework  \
# rochester mn indie                                                                  0.342489
# drivers license                                                                     0.578682
# Mood (feat. iann dior)                                                              0.608401
# positions                                                                           0.632146
# BICHOTA                                                                             0.641070
# ...                                                                                      ...
# Force A                                                                             0.998053
# Saff - Tex-Rec Remix                                                                0.997342
# Jump the Next                                                                       0.912724
# Krim - Marco Asoleda vs Roman Kramer Remix                                          0.992481
# London Groove                                                                       0.952616
#
#                                             Step Asidex  \
# rochester mn indie                             0.334431
# drivers license                                0.713137
# Mood (feat. iann dior)                         0.759808
# positions                                      0.797853
# BICHOTA                                        0.793654
# ...                                                 ...
# Force A                                        0.943165
# Saff - Tex-Rec Remix                           0.944936
# Jump the Next                                  0.960216
# Krim - Marco Asoleda vs Roman Kramer Remix     0.944762
# London Groove                                  0.897184
#
#                                             Carretta - David Carretta Remix  \
# rochester mn indie                                                 0.296641
# drivers license                                                    0.567673
# Mood (feat. iann dior)                                             0.729584
# positions                                                          0.734481
# BICHOTA                                                            0.755734
# ...                                                                     ...
# Force A                                                            0.930378
# Saff - Tex-Rec Remix                                               0.925464
# Jump the Next                                                      0.980555
# Krim - Marco Asoleda vs Roman Kramer Remix                         0.953340
# London Groove                                                      0.920085
#
#                                             Coupe Drug  Tokio Beatz   Force A  \
# rochester mn indie                            0.458771     0.273827  0.315849
# drivers license                               0.608904     0.614280  0.587354
# Mood (feat. iann dior)                        0.723735     0.706965  0.630964
# positions                                     0.748842     0.707305  0.649252
# BICHOTA                                       0.766269     0.711927  0.662556
# ...                                                ...          ...       ...
# Force A                                       0.929951     0.967260  1.000000
# Saff - Tex-Rec Remix                          0.931244     0.974596  0.998198
# Jump the Next                                 0.968289     0.953899  0.921331
# Krim - Marco Asoleda vs Roman Kramer Remix    0.957069     0.972954  0.991652
# London Groove                                 0.914701     0.939629  0.950804
#
#                                             Saff - Tex-Rec Remix  \
# rochester mn indie                                      0.320175
# drivers license                                         0.596418
# Mood (feat. iann dior)                                  0.634664
# positions                                               0.656206
# BICHOTA                                                 0.664010
# ...                                                          ...
# Force A                                                 0.998198
# Saff - Tex-Rec Remix                                    1.000000
# Jump the Next                                           0.925977
# Krim - Marco Asoleda vs Roman Kramer Remix              0.992119
# London Groove                                           0.952149
#
#                                             Jump the Next  \
# rochester mn indie                               0.244820
# drivers license                                  0.619886
# Mood (feat. iann dior)                           0.767626
# positions                                        0.775245
# BICHOTA                                          0.774183
# ...                                                   ...
# Force A                                          0.921331
# Saff - Tex-Rec Remix                             0.925977
# Jump the Next                                    1.000000
# Krim - Marco Asoleda vs Roman Kramer Remix       0.949535
# London Groove                                    0.933344
#
#                                             Krim - Marco Asoleda vs Roman Kramer Remix  \
# rochester mn indie                                                            0.326477
# drivers license                                                               0.584717
# Mood (feat. iann dior)                                                        0.648837
# positions                                                                     0.667680
# BICHOTA                                                                       0.673132
# ...                                                                                ...
# Force A                                                                       0.991652
# Saff - Tex-Rec Remix                                                          0.992119
# Jump the Next                                                                 0.949535
# Krim - Marco Asoleda vs Roman Kramer Remix                                    1.000000
# London Groove                                                                 0.975088
#
#                                             London Groove
# rochester mn indie                               0.219887
# drivers license                                  0.557085
# Mood (feat. iann dior)                           0.622433
# positions                                        0.634459
# BICHOTA                                          0.618459
# ...                                                   ...
# Force A                                          0.950804
# Saff - Tex-Rec Remix                             0.952149
# Jump the Next                                    0.933344
# Krim - Marco Asoleda vs Roman Kramer Remix       0.975088
# London Groove                                    1.000000
#
# [36525 rows x 36525 columns]

# %% [markdown]
# Recommend Swedish Tropical House

# %%
df_songs_sim_genre[genre_choice].sort_values(ascending=False)[1:31]
# Out:
# The Arrival - 2015 Remaster                                            0.671297
# Year 2019                                                              0.659593
# Nucleus                                                                0.651140
# Glimpse of a Dream (2019)                                              0.646052
# Frederick's Bass Tester #16                                            0.645305
# Kitty - 2013 Mix                                                       0.644866
# Return 2 Dust                                                          0.634321
# Streetlights                                                           0.632911
# Since 2016 Didn't Kill Me (Next Year Might...)                         0.619598
# Weißes Rauschen: Baby Schlafhilfe                                      0.616521
# A State Of Trance (ASOT 997) - ASOT Year Mix 2020 Outro                0.613270
# Faithful Servant                                                       0.609140
# Drive-In Saturday - German Single Edit; 2015 Remaster                  0.608582
# Into the Flame - 2012 Remaster                                         0.606016
# It's the Most Wonderful Time of the Year                               0.601824
# Tibbie Dunbar (mog) - 2011 Remaster                                    0.601310
# Year of the Dog                                                        0.601003
# Evermore                                                               0.600918
# Entr'acte-Valse                                                        0.600285
# Frederick's Bass Tester #19                                            0.599620
# The Many Things That Life Could Bring - Live 2012                      0.597809
# The Years All Pass Me By                                               0.594367
# The Milagro Beanfield War: Theme - From "The Milagro Beanfield War"    0.593094
# The Moth (Medley) - 2004 Remaster                                      0.592764
# The Winter Ends - Demo January 2013                                    0.591737
# Stop and Stare                                                         0.590456
# Misery, Shining Like a Bird (Demo 2010)                                0.590000
# When a Man Loves a Woman                                               0.587773
# Everything                                                             0.586522
# Down the Garden Path                                                   0.585899
# Name: rochester mn indie, dtype: float64

# %%
song_list = list(df_songs_sim_genre[genre_choice].sort_values(ascending=False)[1:31].index)
song_list
# Out:
# ['The Arrival - 2015 Remaster',
#  'Year 2019',
#  'Nucleus',
#  'Glimpse of a Dream (2019)',
#  "Frederick's Bass Tester #16",
#  'Kitty - 2013 Mix',
#  'Return 2 Dust',
#  'Streetlights',
#  "Since 2016 Didn't Kill Me (Next Year Might...)",
#  'Weißes Rauschen: Baby Schlafhilfe',
#  'A State Of Trance (ASOT 997) - ASOT Year Mix 2020 Outro',
#  'Faithful Servant',
#  'Drive-In Saturday - German Single Edit; 2015 Remaster',
#  'Into the Flame - 2012 Remaster',
#  "It's the Most Wonderful Time of the Year",
#  'Tibbie Dunbar (mog) - 2011 Remaster',
#  'Year of the Dog',
#  'Evermore',
#  "Entr'acte-Valse",
#  "Frederick's Bass Tester #19",
#  'The Many Things That Life Could Bring - Live 2012',
#  'The Years All Pass Me By',
#  'The Milagro Beanfield War: Theme - From "The Milagro Beanfield War"',
#  'The Moth (Medley) - 2004 Remaster',
#  'The Winter Ends - Demo January 2013',
#  'Stop and Stare',
#  'Misery, Shining Like a Bird (Demo 2010)',
#  'When a Man Loves a Woman',
#  'Everything',
#  'Down the Garden Path']

# %% [markdown]
# ### 5.3 Nearest Neighbors

# %%
# from sklearn.neighbors import NearestNeighbors

# %%
# nn = NearestNeighbors(n_neighbors=10)
# nn.fit(df_recommender2)
# distances, indices = nn.kneighbors(df_recommender2)

# %% [markdown]
# ### 5.4 Spotify API

# %%
def get_song():
    song_chosen = False

    while not song_chosen: 
        song_choice = input("What song sparks joy in your life?: ")
        try: 
            song_query = df_recommender2.loc[song_choice]
        except KeyError: 
            song_choice = ""
            print("Sorry! That song is not in our limited dataset. Please choose another song")
            song_chosen = False
        if song_choice != "":
            song_chosen = True
    return song_choice

# %%
import spotipy
from spotipy.oauth2 import SpotifyOAuth

# %%
CLIENT_ID = "da356cb5fb1c4b3b9546ada6dd4dbd12"
CLIENT_SECRET = "e50029f63a2e4cf589f0f5ec903af115"

# %%
song_query = "champagne problems"

# %%
sp = spotipy.Spotify(
    auth_manager=SpotifyOAuth(client_id=CLIENT_ID,
                              client_secret=CLIENT_SECRET,
                              redirect_uri="http://example.com",
                              scope="playlist-modify-public",
                              show_dialog=True,
                             cache_path="token.txt"))
user_id = sp.current_user()["id"]

# %%
# top_20_songs = list(songs_sim[song_query].sort_values(ascending=False).head(20).index)
# top_20_songs

# %%
def find_song(top_20_songs):
    song_uris = []
    for song in top_20_songs: 
        result = sp.search(q=f"track:{song}", type="track")
        try: 
            uri = result['tracks']['items'][0]['uri']
            song_uris.append(uri)
        except IndexError:
            print(f"{song} doesn't exist in Spotify. Skipped.")
    return song_uris

# %%
find_song(genre_choice)
# Out:
# ['spotify:track:2VJOpzv5sBpstCX9venJr5',
#  'spotify:track:7MAibcTli4IisCtbHKrGMh',
#  'spotify:track:4iJyoBOLtHqaGxP12qzhQI',
#  'spotify:track:3FAJ6O0NOHQV8Mc5Ri6ENp',
#  'spotify:track:4iJyoBOLtHqaGxP12qzhQI',
#  'spotify:track:5QO79kh1waicV47BqGRL3g',
#  'spotify:track:7MAibcTli4IisCtbHKrGMh',
#  'spotify:track:4iJyoBOLtHqaGxP12qzhQI',
#  'spotify:track:2VJOpzv5sBpstCX9venJr5',
#  'spotify:track:6Pf1Y9DjaDLp53XyLXpaSg',
#  'spotify:track:6fRxMU4LWwyaSSowV441IU',
#  'spotify:track:67BtfxlNbhBmCDR2L2l8qd',
#  'spotify:track:6Pf1Y9DjaDLp53XyLXpaSg',
#  'spotify:track:3Ofmpyhv5UAQ70mENzB277',
#  'spotify:track:67BtfxlNbhBmCDR2L2l8qd',
#  'spotify:track:7MAibcTli4IisCtbHKrGMh',
#  'spotify:track:3Ofmpyhv5UAQ70mENzB277',
#  'spotify:track:4iJyoBOLtHqaGxP12qzhQI']

# %%
playlist_name = f"Your {genre_choice.title()} Playlist"
playlist = sp.user_playlist_create(user='1184735198', name=playlist_name)
sp.playlist_add_items(playlist_id=playlist['id'], items=find_song(genre_choice))
# Out:
# {'snapshot_id': 'Miw3MjcxYzg4MjZmMmE2MDk0MzdjYjBhOWFkMGJiNjM2ODI4NTBiMTRi'}
