# %% [markdown]
# # Spotify Song Popularity Predictor and Genre Recommendation System

# %%
# !pip install spotipy

# %%
import pandas as pd
import numpy as np
import random
from scipy import sparse
from sklearn.metrics.pairwise import pairwise_distances, cosine_distances, cosine_similarity
from sklearn.preprocessing import MinMaxScaler
from datetime import datetime

# %matplotlib inline

# %% [markdown]
# ## 5. Song Recommender Model

# %%
df_recommender = pd.read_csv("../datasets/data_recommender.csv")
df_recommender
# Out:
#         acousticness                                   artists  danceability  \
# 0           0.991000                           ['Mamie Smith']         0.598
# 1           0.643000                 ["Screamin' Jay Hawkins"]         0.852
# 2           0.993000                           ['Mamie Smith']         0.647
# 3           0.000173                       ['Oscar Velazquez']         0.730
# 4           0.295000                                  ['Mixe']         0.704
# ...              ...                                       ...           ...
# 159329      0.995000  ['Ludovico Einaudi', 'Johannes Bornlöf']         0.297
# 159330      0.995000  ['Ludovico Einaudi', 'Johannes Bornlöf']         0.343
# 159331      0.988000  ['Ludovico Einaudi', 'Johannes Bornlöf']         0.316
# 159332      0.795000                          ['Alessia Cara']         0.429
# 159333      0.920000                          ['Taylor Swift']         0.462
#
#         energy  explicit  instrumentalness  key  liveness  loudness  mode  \
# 0       0.2240         0          0.000522    5    0.3790   -12.628     0
# 1       0.5170         0          0.026400    5    0.0809    -7.261     0
# 2       0.1860         0          0.000018    0    0.5190   -12.098     1
# 3       0.7980         0          0.801000    2    0.1280    -7.311     1
# 4       0.7070         1          0.000246   10    0.4020    -6.036     0
# ...        ...       ...               ...  ...       ...       ...   ...
# 159329  0.0287         0          0.908000    8    0.0995   -30.008     1
# 159330  0.0165         0          0.878000    9    0.0774   -30.915     0
# 159331  0.0573         0          0.879000    3    0.1200   -24.121     1
# 159332  0.2110         0          0.000000    4    0.1960   -11.665     1
# 159333  0.2400         1          0.000000    0    0.1130   -12.077     1
#
#                                                      name  popularity  \
# 0                                Keep A Song In Your Soul        0.12
# 1                                    I Put A Spell On You        0.07
# 2                                            Golfing Papa        0.04
# 3       True House Music - Xavier Santos & Carlos Gomi...        0.17
# 4                                               Xuniverxe        0.02
# ...                                                   ...         ...
# 159329                                     Nuvole bianche        0.00
# 159330                                        Una Mattina        0.00
# 159331                                              Night        0.00
# 159332                                      A Little More        0.00
# 159333                                 champagne problems        0.69
#
#         speechiness    tempo  valence  year  duration_mins
# 0            0.0936  149.976   0.6340  1920           2.81
# 1            0.0534   86.889   0.9500  1920           2.50
# 2            0.1740   97.600   0.6890  1920           2.73
# 3            0.0425  127.997   0.0422  1920           7.03
# 4            0.0768  122.076   0.2990  1920           2.75
# ...             ...      ...      ...   ...            ...
# 159329       0.0564  141.636   0.0678  2021           5.82
# 159330       0.0455  126.970   0.1510  2021           3.44
# 159331       0.0515   81.070   0.0373  2021           5.06
# 159332       0.0360   94.710   0.2280  2021           2.41
# 159333       0.0377  171.319   0.3200  2021           4.07
#
# [159334 rows x 17 columns]

# %%
df_recommender.shape
# Out:
# (159334, 17)

# %% [markdown]
# ### 5.1 Preprocessing

# %% [markdown]
# Since the dataframe still contains almost 160,000 rows, it's not feasible to create a recommender with all those songs. Instead, we'll be taking a subset of the dataframe with songs from 1990 onwards. In addition, all duplicated song versions from the SAME artist will be dropped, keeping only the version with the highest popularity.
#
# We will still keep the same song sung by different artist to ensure that songs with identical titles are not deleted.

# %% [markdown]
# #### 5.1.1 Main Dataset of Songs

# %%
df_recommender = df_recommender.sort_values('popularity', ascending=False)
df_recommender.drop_duplicates(subset=['artists', 'name'], keep='first', inplace=True)

# %%
df_recommender_2000 = df_recommender[df_recommender.year >= 2000]
df_recommender_2000.describe()['year']
# Out:
# count    36381.000000
# mean      2011.921003
# std          6.130138
# min       2000.000000
# 25%       2007.000000
# 50%       2013.000000
# 75%       2017.000000
# max       2021.000000
# Name: year, dtype: float64

# %%
df_recommender_2000.shape
# Out:
# (36381, 17)

# %%
df_recommender_2000[df_recommender_2000.name.duplicated()]['name'].value_counts().head(50)
# Out:
# 2000 Years                                                     51
# Happy New Year                                                 21
# 7 Years                                                        18
# Stay                                                           16
# New Year                                                       16
# Have Yourself a Merry Little Christmas                         15
# Year 2000                                                      15
# It's the Most Wonderful Time of the Year                       12
# Neujahrsgruß / New Year's Address / Allocution du Nouvel An    12
# Home                                                           12
# 2000 Light Years from Home                                     12
# Hold On                                                        11
# 2000 Years Ago                                                 10
# A Thousand Years                                               10
# Winter Wonderland                                              10
# Intro                                                           9
# Radetzky-Marsch, Op. 228                                        9
# Happy New Year 2021                                             9
# Believe                                                         8
# Smile                                                           8
# You                                                             8
# Santa Baby                                                      8
# Forever                                                         8
# That Time of Year                                               8
# Beautiful                                                       8
# Background for 2021                                             8
# Daylight                                                        7
# Alone                                                           7
# Breathe                                                         7
# Without You                                                     7
# Broken                                                          7
# Heaven                                                          7
# Monster                                                         7
# Trouble                                                         7
# Wake Up                                                         7
# Ghost                                                           7
# Save Me                                                         7
# The Year 2000                                                   7
# In the Year 2000                                                7
# Love Me                                                         6
# Happy New Year 2019                                             6
# 2021                                                            6
# Love                                                            6
# New Year Eve 2019                                               6
# Golden Years                                                    6
# Runaway                                                         6
# Untitled                                                        6
# Hallelujah                                                      6
# Years                                                           6
# Closer                                                          6
# Name: name, dtype: int64

# %%
drop_features = ['explicit', 'key', 'mode', 'year', 'duration_mins', 'artists', 'popularity']
scale_features = ['loudness', 'tempo']
features = ['acousticness', 'danceability', 'energy', 'instrumentalness', 'liveness', 'speechiness', 'valence']

# %%
df_recommender_2000 = df_recommender_2000.drop(drop_features, axis=1)
df_recommender_2000
# Out:
#         acousticness  danceability  energy  instrumentalness  liveness  \
# 18796       0.721000         0.585   0.436          0.000013    0.1050
# 18617       0.221000         0.700   0.722          0.000000    0.2720
# 18620       0.468000         0.737   0.802          0.000000    0.0931
# 18712       0.212000         0.863   0.666          0.000493    0.1030
# 18634       0.401000         0.731   0.573          0.000052    0.1130
# ...              ...           ...     ...               ...       ...
# 129279      0.080200         0.254   0.633          0.000871    0.0551
# 129281      0.006780         0.753   0.691          0.705000    0.0893
# 129283      0.002270         0.741   0.825          0.068200    0.1670
# 129287      0.008510         0.626   0.533          0.556000    0.1170
# 129289      0.000276         0.689   0.832          0.447000    0.0579
#
#         loudness                            name  speechiness    tempo  \
# 18796     -8.761                 drivers license       0.0601  143.874
# 18617     -3.558          Mood (feat. iann dior)       0.0369   90.989
# 18620     -4.771                       positions       0.0878  144.015
# 18712     -4.158                         BICHOTA       0.1520  163.908
# 18634    -10.059                          DÁKITI       0.0544  109.928
# ...          ...                             ...          ...      ...
# 129279    -8.697                        NINETEEN       0.0321   75.980
# 129281    -9.075             Azrael - Dahu Remix       0.0306  122.007
# 129283    -2.924  Speak Up (feat. Wynter Gordon)       0.0720  128.020
# 129287   -13.078                      Lost Vegas       0.0367  127.018
# 129289    -4.298      Move - Tune Brothers Remix       0.0756  127.988
#
#         valence
# 18796     0.132
# 18617     0.756
# 18620     0.682
# 18712     0.838
# 18634     0.145
# ...         ...
# 129279    0.516
# 129281    0.231
# 129283    0.319
# 129287    0.377
# 129289    0.896
#
# [36381 rows x 10 columns]

# %%
def min_max_scale(X, range=(0, 1)):
    mi, ma = range
    X_std = (X - X.min()) / (X.max() - X.min())
    X_scaled = X_std * (ma - mi) + mi
    return X_scaled

# %%
for feature in scale_features: 
    df_recommender_2000[feature] = min_max_scale(df_recommender_2000[feature])
    print(df_recommender_2000[feature].describe())
# Out:
# count    36381.000000
# mean         0.803281
# std          0.077806
# min          0.000000
# 25%          0.778138
# 50%          0.821970
# 75%          0.852207
# max          1.000000
# Name: loudness, dtype: float64
# count    36381.000000
# mean         0.553333
# std          0.128064
# min          0.000000
# 25%          0.450918
# 50%          0.563180
# 75%          0.627107
# max          1.000000
# Name: tempo, dtype: float64

# %%
df_recommender_2000 = df_recommender_2000.set_index('name', drop=True)
df_recommender_2000.head()
# Out:
#                         acousticness  danceability  energy  instrumentalness  \
# name
# drivers license                0.721         0.585   0.436          0.000013
# Mood (feat. iann dior)         0.221         0.700   0.722          0.000000
# positions                      0.468         0.737   0.802          0.000000
# BICHOTA                        0.212         0.863   0.666          0.000493
# DÁKITI                         0.401         0.731   0.573          0.000052
#
#                         liveness  loudness  speechiness     tempo  valence
# name
# drivers license           0.1050  0.789966       0.0601  0.648215    0.132
# Mood (feat. iann dior)    0.2720  0.880072       0.0369  0.409945    0.756
# positions                 0.0931  0.859065       0.0878  0.648851    0.682
# BICHOTA                   0.1030  0.869681       0.1520  0.738477    0.838
# DÁKITI                    0.1130  0.767487       0.0544  0.495274    0.145

# %% [markdown]
# #### 5.1.2 Genre Dataset

# %%
df_genres = pd.read_csv("../datasets/data_by_genres_cleaned.csv", index_col=['genres'])
df_genres.head()
# Out:
#                         acousticness  danceability    energy  \
# genres
# 21st century classical      0.754600      0.284100  0.159580
# 432hz                       0.485515      0.312000  0.391678
# 8-bit                       0.028900      0.673000  0.950000
# []                          0.535793      0.546937  0.485430
# a cappella                  0.694276      0.516172  0.330533
#
#                         instrumentalness  liveness   loudness  speechiness  \
# genres
# 21st century classical          0.484374  0.168580 -22.153400     0.062060
# 432hz                           0.477250  0.265940 -18.131267     0.071717
# 8-bit                           0.630000  0.069000  -7.899000     0.292000
# []                              0.278442  0.220970 -11.624754     0.101511
# a cappella                      0.036080  0.222983 -12.656547     0.083627
#
#                              tempo   valence  popularity  key  mode  \
# genres
# 21st century classical   91.351000  0.143380    0.066000    4     1
# 432hz                   118.900933  0.236483    0.412000   11     1
# 8-bit                   192.816000  0.997000    0.000000    5     1
# []                      116.068980  0.486361    0.123508    7     1
# a cappella              105.506031  0.454077    0.390862    7     1
#
#                         duration_mins
# genres
# 21st century classical           5.88
# 432hz                           17.46
# 8-bit                            2.22
# []                               4.16
# a cappella                       3.36

# %%
df_genres = df_genres.sort_values('popularity', ascending=False)
df_genres.head(30)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-26e5effabc22> in <module>
# ----> 1 df_genres = df_genres.sort_values('popularity', ascending=False)
#       2 df_genres.head(30)
#
# NameError: name 'df_genres' is not defined

# %%
for feature in scale_features: 
    df_genres[feature] = min_max_scale(df_genres[feature])
    print(df_genres[feature].describe())
# Out:
# count    3232.000000
# mean        0.760296
# std         0.126312
# min         0.000000
# 25%         0.714633
# 50%         0.792946
# 75%         0.844711
# max         1.000000
# Name: loudness, dtype: float64
# count    3232.000000
# mean        0.387396
# std         0.115094
# min         0.000000
# 25%         0.319488
# 50%         0.390281
# 75%         0.444143
# max         1.000000
# Name: tempo, dtype: float64

# %% [markdown]
# Re-organising columns

# %%
column_order = list(df_recommender_2000.columns)
df_genres = df_genres[column_order]
df_genres.head(30)
# Out:
#                           acousticness  danceability    energy  \
# genres
# chinese electropop            0.002570      0.660000  0.787000
# korean mask singer            0.238000      0.658000  0.749000
# yaoi                          0.006550      0.603000  0.964000
# dutch rap pop                 0.216000      0.767000  0.643000
# rochester mn indie            0.034700      0.655000  0.487000
# dong-yo                       0.259000      0.829000  0.886000
# afroswing                     0.171333      0.758333  0.512000
# j-rap                         0.096100      0.648000  0.904000
# estonian pop                  0.285000      0.458000  0.696000
# irish pop                     0.308600      0.474750  0.513625
# musical advocacy              0.176500      0.563500  0.544500
# alberta hip hop               0.330000      0.885000  0.685000
# channel islands indie         0.147000      0.625000  0.763000
# newcastle nsw indie           0.003920      0.498000  0.810000
# instrumental grime            0.341453      0.743933  0.631533
# guatemalan pop                0.622000      0.591000  0.672000
# rock chapin                   0.622000      0.591000  0.672000
# swedish tropical house        0.022500      0.632000  0.575000
# london rap                    0.142567      0.698333  0.500000
# japanese teen pop             0.014870      0.607667  0.899333
# indonesian r&b                0.251500      0.616000  0.510000
# chinese hip hop               0.359000      0.409000  0.678000
# dembow                        0.167690      0.817400  0.723000
# scam rap                      0.184608      0.829222  0.700667
# irish indie                   0.988000      0.521000  0.088900
# future house                  0.005210      0.609000  0.885000
# finnish alternative rock      0.000109      0.600000  0.796000
# german pop rock               0.299750      0.618400  0.551400
# mexican pop punk              0.009040      0.488000  0.897000
# scandinavian r&b              0.388000      0.705000  0.433000
#
#                           instrumentalness  liveness  loudness  speechiness  \
# genres
# chinese electropop                0.000000  0.323000  0.906223     0.032000
# korean mask singer                0.000002  0.272000  0.947077     0.063400
# yaoi                              0.000003  0.143000  0.949114     0.048700
# dutch rap pop                     0.000104  0.080600  0.890308     0.101000
# rochester mn indie                0.897000  0.271000  0.820842     0.033000
# dong-yo                           0.000000  0.055900  0.977775     0.112000
# afroswing                         0.000033  0.101033  0.831536     0.211000
# j-rap                             0.000002  0.062900  0.906901     0.078600
# estonian pop                      0.000000  0.123000  0.902451     0.040200
# irish pop                         0.024295  0.146075  0.815918     0.057700
# musical advocacy                  0.000017  0.086850  0.742715     0.039900
# alberta hip hop                   0.000000  0.148000  0.860038     0.062700
# channel islands indie             0.010600  0.214000  0.896040     0.129000
# newcastle nsw indie               0.007170  0.063500  0.919472     0.026300
# instrumental grime                0.010906  0.098587  0.860380     0.153467
# guatemalan pop                    0.000000  0.112000  0.933300     0.037500
# rock chapin                       0.000000  0.112000  0.933300     0.037500
# swedish tropical house            0.000002  0.104000  0.858806     0.029000
# london rap                        0.000000  0.093700  0.837746     0.198000
# japanese teen pop                 0.000006  0.193833  0.929814     0.051467
# indonesian r&b                    0.000000  0.087400  0.829604     0.165450
# chinese hip hop                   0.000005  0.167000  0.827304     0.087800
# dembow                            0.001166  0.104500  0.876908     0.148310
# scam rap                          0.000031  0.100042  0.907947     0.282722
# irish indie                       0.182000  0.096500  0.532495     0.050700
# future house                      0.000012  0.336000  0.884173     0.064200
# finnish alternative rock          0.000052  0.484000  0.909013     0.027500
# german pop rock                   0.028040  0.126920  0.796847     0.032500
# mexican pop punk                  0.000059  0.311000  0.858177     0.114000
# scandinavian r&b                  0.134000  0.084100  0.777649     0.204000
#
#                              tempo   valence
# genres
# chinese electropop        0.535536  0.199000
# korean mask singer        0.448493  0.442000
# yaoi                      0.489123  0.796000
# dutch rap pop             0.721269  0.536000
# rochester mn indie        0.521566  0.045400
# dong-yo                   0.356510  0.777000
# afroswing                 0.270224  0.480333
# j-rap                     0.402578  0.728000
# estonian pop              0.748831  0.418000
# irish pop                 0.329866  0.265238
# musical advocacy          0.216673  0.320500
# alberta hip hop           0.256234  0.937000
# channel islands indie     0.181860  0.721000
# newcastle nsw indie       0.123309  0.594000
# instrumental grime        0.415988  0.594000
# guatemalan pop            0.521732  0.267000
# rock chapin               0.521732  0.267000
# swedish tropical house    0.190385  0.188000
# london rap                0.330101  0.502333
# japanese teen pop         0.438332  0.742333
# indonesian r&b            0.646845  0.300500
# chinese hip hop           0.189927  0.168000
# dembow                    0.331355  0.741700
# scam rap                  0.400208  0.465056
# irish indie               0.358993  0.047900
# future house              0.422265  0.760000
# finnish alternative rock  0.296319  0.750000
# german pop rock           0.361870  0.508800
# mexican pop punk          0.734973  0.814000
# scandinavian r&b          0.708095  0.602000

# %% [markdown]
# ### 5.2 Cosine Similarity for Songs
#
# In this section, we explore the cosine similarity between songs and create an algorithm that returns the top 30 most similar songs to a particular song chosen. In this case, we use the song "drivers license" as our reference.

# %%
sim_matrix = cosine_similarity(df_recommender_2000)
songs_sim = pd.DataFrame(sim_matrix, columns=df_recommender_2000.index, index=df_recommender_2000.index)
songs_sim

# %%
songs_sim['drivers license'].sort_values(ascending=False).head(20)

# %% [markdown]
# These are the top 30 songs similar to drivers license.

# %% [markdown]
# ### 5.3 Cosine Similarity for Genres
#
# This is the main focus for the recommender system - to build a playlist of 30 songs which are most similar to a particular genre selected and add the playlist to my Spotify using the Spotify API.

# %%
genres_to_recc = [genre for genre in list(df_genres.head(30).index)]
genres_to_recc[25:]
# Out:
# ['future house',
#  'finnish alternative rock',
#  'german pop rock',
#  'mexican pop punk',
#  'scandinavian r&b']

# %% [markdown]
# Let's recommend songs with similar features to swedish tropical house

# %%
genre_choice = 'newcastle nsw indie'

# %%
df_genre_recc = pd.concat([pd.DataFrame(df_genres.loc[genre_choice]).T, df_recommender_2000], axis=0)
df_genre_recc.head()
# Out:
#                         acousticness  danceability  energy  instrumentalness  \
# newcastle nsw indie          0.00392         0.498   0.810          0.007170
# drivers license              0.72100         0.585   0.436          0.000013
# Mood (feat. iann dior)       0.22100         0.700   0.722          0.000000
# positions                    0.46800         0.737   0.802          0.000000
# BICHOTA                      0.21200         0.863   0.666          0.000493
#
#                         liveness  loudness  speechiness     tempo  valence
# newcastle nsw indie       0.0635  0.919472       0.0263  0.123309    0.594
# drivers license           0.1050  0.789966       0.0601  0.648215    0.132
# Mood (feat. iann dior)    0.2720  0.880072       0.0369  0.409945    0.756
# positions                 0.0931  0.859065       0.0878  0.648851    0.682
# BICHOTA                   0.1030  0.869681       0.1520  0.738477    0.838

# %%
start_time = datetime.now()
print(f"Recommending {genre_choice} music...")
sim_matrix_genre = cosine_similarity(df_genre_recc)
songs_sim_genre = pd.DataFrame(sim_matrix_genre, columns=df_genre_recc.index, index=df_genre_recc.index)
songs_sim_genre

end_time = datetime.now()
print('Duration: {}'.format(end_time - start_time))
# Out:
# Recommending newcastle nsw indie music...
# Duration: 0:00:20.597138

# %%
df_songs_sim_genre = pd.DataFrame(sim_matrix_genre, columns=df_genre_recc.index, index=df_genre_recc.index)
df_songs_sim_genre
# Out:
#                                 newcastle nsw indie  drivers license  \
# newcastle nsw indie                        1.000000         0.724687
# drivers license                            0.724687         1.000000
# Mood (feat. iann dior)                     0.953603         0.831729
# positions                                  0.905278         0.912169
# BICHOTA                                    0.899158         0.850600
# ...                                             ...              ...
# NINETEEN                                   0.968849         0.790323
# Azrael - Dahu Remix                        0.809486         0.761643
# Speak Up (feat. Wynter Gordon)             0.925539         0.840220
# Lost Vegas                                 0.832912         0.781530
# Move - Tune Brothers Remix                 0.922086         0.741348
#
#                                 Mood (feat. iann dior)  positions   BICHOTA  \
# newcastle nsw indie                           0.953603   0.905278  0.899158
# drivers license                               0.831729   0.912169  0.850600
# Mood (feat. iann dior)                        1.000000   0.973148  0.973901
# positions                                     0.973148   1.000000  0.978995
# BICHOTA                                       0.973901   0.978995  1.000000
# ...                                                ...        ...       ...
# NINETEEN                                      0.955534   0.937570  0.926328
# Azrael - Dahu Remix                           0.829228   0.834077  0.838302
# Speak Up (feat. Wynter Gordon)                0.942901   0.938627  0.939999
# Lost Vegas                                    0.876002   0.875090  0.893827
# Move - Tune Brothers Remix                    0.944957   0.925382  0.948050
#
#                                   DÁKITI  Therefore I Am  WITHOUT YOU  \
# newcastle nsw indie             0.843406        0.876148     0.914448
# drivers license                 0.960201        0.828661     0.892910
# Mood (feat. iann dior)          0.908220        0.951011     0.975167
# positions                       0.949464        0.939219     0.968827
# BICHOTA                         0.912725        0.969215     0.974853
# ...                                  ...             ...          ...
# NINETEEN                        0.858533        0.870766     0.925681
# Azrael - Dahu Remix             0.855005        0.841463     0.850032
# Speak Up (feat. Wynter Gordon)  0.944521        0.895099     0.949330
# Lost Vegas                      0.861264        0.890730     0.892009
# Move - Tune Brothers Remix      0.833433        0.925612     0.915906
#
#                                  Whoopty     34+35  ...  \
# newcastle nsw indie             0.908123  0.908271  ...
# drivers license                 0.852326  0.891436  ...
# Mood (feat. iann dior)          0.979637  0.977329  ...
# positions                       0.979259  0.972211  ...
# BICHOTA                         0.997912  0.975046  ...
# ...                                  ...       ...  ...
# NINETEEN                        0.937656  0.910813  ...
# Azrael - Dahu Remix             0.836242  0.863348  ...
# Speak Up (feat. Wynter Gordon)  0.942803  0.965288  ...
# Lost Vegas                      0.892912  0.896859  ...
# Move - Tune Brothers Remix      0.948225  0.914515  ...
#
#                                 Machete - Original Mix   Horizon  \
# newcastle nsw indie                           0.682731  0.832716
# drivers license                               0.689322  0.749565
# Mood (feat. iann dior)                        0.736795  0.842029
# positions                                     0.713929  0.846456
# BICHOTA                                       0.713632  0.849238
# ...                                                ...       ...
# NINETEEN                                      0.681212  0.844028
# Azrael - Dahu Remix                           0.934347  0.993045
# Speak Up (feat. Wynter Gordon)                0.823879  0.907538
# Lost Vegas                                    0.913901  0.988929
# Move - Tune Brothers Remix                    0.790865  0.939102
#
#                                 Loungin' - VIP  Levitate   My Love  NINETEEN  \
# newcastle nsw indie                   0.796043  0.776753  0.808266  0.968849
# drivers license                       0.775348  0.725985  0.804517  0.790323
# Mood (feat. iann dior)                0.825338  0.799567  0.867232  0.955534
# positions                             0.843540  0.803407  0.879320  0.937570
# BICHOTA                               0.848772  0.813478  0.903444  0.926328
# ...                                        ...       ...       ...       ...
# NINETEEN                              0.837631  0.781472  0.842520  1.000000
# Azrael - Dahu Remix                   0.982756  0.994410  0.976386  0.808118
# Speak Up (feat. Wynter Gordon)        0.907960  0.870232  0.927903  0.929348
# Lost Vegas                            0.986437  0.985143  0.994134  0.851987
# Move - Tune Brothers Remix            0.919576  0.908658  0.937082  0.932845
#
#                                 Azrael - Dahu Remix  \
# newcastle nsw indie                        0.809486
# drivers license                            0.761643
# Mood (feat. iann dior)                     0.829228
# positions                                  0.834077
# BICHOTA                                    0.838302
# ...                                             ...
# NINETEEN                                   0.808118
# Azrael - Dahu Remix                        1.000000
# Speak Up (feat. Wynter Gordon)             0.910081
# Lost Vegas                                 0.986976
# Move - Tune Brothers Remix                 0.913608
#
#                                 Speak Up (feat. Wynter Gordon)  Lost Vegas  \
# newcastle nsw indie                                   0.925539    0.832912
# drivers license                                       0.840220    0.781530
# Mood (feat. iann dior)                                0.942901    0.876002
# positions                                             0.938627    0.875090
# BICHOTA                                               0.939999    0.893827
# ...                                                        ...         ...
# NINETEEN                                              0.929348    0.851987
# Azrael - Dahu Remix                                   0.910081    0.986976
# Speak Up (feat. Wynter Gordon)                        1.000000    0.922458
# Lost Vegas                                            0.922458    1.000000
# Move - Tune Brothers Remix                            0.922860    0.952072
#
#                                 Move - Tune Brothers Remix
# newcastle nsw indie                               0.922086
# drivers license                                   0.741348
# Mood (feat. iann dior)                            0.944957
# positions                                         0.925382
# BICHOTA                                           0.948050
# ...                                                    ...
# NINETEEN                                          0.932845
# Azrael - Dahu Remix                               0.913608
# Speak Up (feat. Wynter Gordon)                    0.922860
# Lost Vegas                                        0.952072
# Move - Tune Brothers Remix                        1.000000
#
# [36382 rows x 36382 columns]

# %%
df_songs_sim_genre[genre_choice].sort_values(ascending=False)[1:31]
# Out:
# Beer Never Broke My Heart                                   0.987315
# Must've Never Met You                                       0.986413
# Young                                                       0.986351
# Unstoppable                                                 0.985955
# Windows Are Rolled Down                                     0.985551
# Get Back                                                    0.985430
# Come & Get It                                               0.985272
# Primo Victoria                                              0.985169
# Steal My Girl                                               0.984567
# City                                                        0.984371
# Hallelujah                                                  0.984324
# Neverender                                                  0.983602
# That Was A Crazy Game Of Poker                              0.983592
# He's Mine                                                   0.983567
# Can I Get an Outlaw                                         0.983308
# Rill Rill                                                   0.983148
# Watch The Wind Blow By                                      0.983055
# Home                                                        0.983045
# The Sun                                                     0.982898
# All American Nightmare                                      0.982810
# Make A Move                                                 0.982568
# Priceless                                                   0.982387
# Right Girl                                                  0.982384
# Blind Eye                                                   0.982172
# The Country Boy Song (feat. Earl Dibbles Jr.)               0.982111
# Tirando la H                                                0.982081
# Stand Up                                                    0.981999
# Son's Gonna Rise (feat. Robert Randolph) - New Radio Mix    0.981948
# Naughty List (with Dixie D’Amelio)                          0.981945
# อย่าหักหลัง                                                 0.981910
# Name: newcastle nsw indie, dtype: float64

# %%
song_list = list(df_songs_sim_genre[genre_choice].sort_values(ascending=False)[1:31].index)
song_list
# Out:
# ['Beer Never Broke My Heart',
#  "Must've Never Met You",
#  'Young',
#  'Unstoppable',
#  'Windows Are Rolled Down',
#  'Get Back',
#  'Come & Get It',
#  'Primo Victoria',
#  'Steal My Girl',
#  'City',
#  'Hallelujah',
#  'Neverender',
#  'That Was A Crazy Game Of Poker',
#  "He's Mine",
#  'Can I Get an Outlaw',
#  'Rill Rill',
#  'Watch The Wind Blow By',
#  'Home',
#  'The Sun',
#  'All American Nightmare',
#  'Make A Move',
#  'Priceless',
#  'Right Girl',
#  'Blind Eye',
#  'The Country Boy Song (feat. Earl Dibbles Jr.)',
#  'Tirando la H',
#  'Stand Up',
#  "Son's Gonna Rise (feat. Robert Randolph) - New Radio Mix",
#  'Naughty List (with Dixie D’Amelio)',
#  'อย่าหักหลัง']

# %% [markdown]
# ### 5.4 Spotify API

# %%
import spotipy
from spotipy.oauth2 import SpotifyOAuth

# %%
# Replace SPOTIFY ID and SPOTIFY_SECRET with your own Spotify details 
CLIENT_ID = SPOTIFY_ID
CLIENT_SECRET = SPOTIFY_SECRET

# %%
sp = spotipy.Spotify(
    auth_manager=SpotifyOAuth(client_id=CLIENT_ID,
                              client_secret=CLIENT_SECRET,
                              redirect_uri="http://example.com",
                              scope="playlist-modify-public",
                              show_dialog=True,
                             cache_path="token.txt"))
user_id = sp.current_user()["id"]

# %%
def find_song(top_20_songs):
    song_uris = []
    for song in top_20_songs: 
        result = sp.search(q=f"track:{song}", type="track")
        try: 
            uri = result['tracks']['items'][0]['uri']
            song_uris.append(uri)
        except IndexError:
            print(f"{song} doesn't exist in Spotify. Skipped.")
    return song_uris

# %% [markdown]
# For loop to generate playlists for top 30 genres and automatically create playlists on Spotify

# %%
for genre in genres_to_recc[25:]: 
    df_genre_recc = pd.concat([pd.DataFrame(df_genres.loc[genre]).T, df_recommender_2000], axis=0)
    start_time = datetime.now()
    print(f"Recommending {genre} music...")
    sim_matrix_genre = cosine_similarity(df_genre_recc)
    songs_sim_genre = pd.DataFrame(sim_matrix_genre, columns=df_genre_recc.index, index=df_genre_recc.index)
    songs_sim_genre
    end_time = datetime.now()
    print('Duration: {}'.format(end_time - start_time))
    
    df_songs_sim_genre = pd.DataFrame(sim_matrix_genre, columns=df_genre_recc.index, index=df_genre_recc.index)
    song_list = list(df_songs_sim_genre[genre].sort_values(ascending=False)[1:31].index)
    
    print(song_list)
    
    playlist_name = f"Sounds like {genre.title()} Playlist"
    playlist = sp.user_playlist_create(user='1184735198', name=playlist_name)
    sp.playlist_add_items(playlist_id=playlist['id'], items=find_song(song_list))
# Out:
# Recommending future house music...
# Duration: 0:00:06.553475
# ["Don't It", "The Remedy (I Won't Worry)", 'Rich Kids - [Middle Cla$$ MIX]', 'Dani California', 'Careful with That Mic...', '&', 'Figured You Out', 'El Ultimo Adios', 'the WORLD', 'Galway Girl', 'Young Volcanoes', 'I Just Wanna Be Mad', 'I Hate Hippies', 'Real Good Man', 'Cheers (Drink To That)', 'Hot Mama', 'One Whole Day (feat. Wiz Khalifa)', 'Raised On It', 'สาปแช่ง พวกแย่งแฟน', 'Little Red Wagon', "Burnin' Up", 'Take It From Me', 'After the Moment', 'Chicks Dig It - Single Edit', 'Overprotected - Radio Edit', 'Somebody To You', 'Ocean Breathes Salty', 'Shark In The Water', 'Swing', "I'm Not Famous"]
# Recommending finnish alternative rock music...
# Duration: 0:00:32.188491
# ['Small Town Boy', 'D.J. D.J.', 'Raise Hell', 'Shake up Christmas 2011 (Official Coca-Cola Christmas Song)', 'Jim Sharp', 'Kiss You', 'Animals - Karaoke Version In the Style of Nickelback', 'Overprotected - Radio Edit', 'Northern Redneck', 'El Ultimo Adios', 'There Goes My Baby', 'Hey Jude', 'Love Me', 'Cool Again', 'In the Shadows', 'Sic Transit Gloria ... Glory Fades', 'Nobody', 'Used to Love U', 'Careful with That Mic...', 'Water', "Don't It", 'インフェルノ', 'Growl', 'สาปแช่ง พวกแย่งแฟน', 'Young Volcanoes', 'Stand Up', 'Christmas This Year', 'Terrorist', 'These Are My People', 'California Love - Original Version']
# Recommending german pop rock music...
# Duration: 0:00:49.226872
# ["I'm A Survivor", 'Donde Quiera Que Estés', 'Heaven', 'จริงใจไม่จริงจัง', 'Young & Alive', 'Aquel Lugar', 'Impossible', 'Dear Fellow Traveller', 'Forever More', 'Mirrors', 'Starving', 'Like I Can', 'Line By Line', 'Let It Burn', 'Stay', 'Happy Does', 'Tu Amor Me Hace Bien - Salsa Version', 'Make Me Better', 'Suede', 'You’ll Think Of Me', "Can't Help but Wait", 'No Te Contaron Mal', 'ฉันมาบอกเขา', 'One in a Million - 2012 Remaster', 'One Call Away', 'No Letting Go', 'Every Day', 'Look Up Child', 'Edge of Desire', "Pretty Good At Drinkin' Beer"]
# Recommending mexican pop punk music...
# Duration: 0:00:30.063082
# ['Los Malaventurados No Lloran', 'Deer Dance', "I Can't Get Nowhere With You - 2011 Remaster", 'Mercy Me', 'Christmas Is My Favorite Time of Year', 'Made To Love', 'Hold On', 'Paint It, Black - (Original Single Mono Version)', 'Fix a Drink', 'American Ride', 'English Love Affair', 'The Good, the Bad and the Dirty', 'Leave The Night On', 'Beat It', 'My Paper Heart', 'Motivation', 'Suds in the Bucket', 'Burned Out Love', 'Everybody Talks', 'Beat It - Studio Version Featuring John Mayer', 'Fire in the Sky - 2009 Remastered Version', "I'm A Believer - Soundtrack Version", "It's Been A Summer", 'Sweet, Sweet, Sweet', "Crazy Eddie's Last Hurrah", '嘘', 'Private Eye', 'Animal', 'Cold - Radio Mix; aka Deep Freeze Mix', '恋の彗星']
# Beat It - Studio Version Featuring John Mayer doesn't exist in Spotify. Skipped.
# I'm A Believer - Soundtrack Version doesn't exist in Spotify. Skipped.
# 恋の彗星 doesn't exist in Spotify. Skipped.
# Recommending scandinavian r&b music...
# Duration: 0:00:32.567601
# ['I Want You Around', 'December 32nd, 2015', 'Cool Yule', 'Bag Lady', 'Mirrors on the Ceiling', 'Wake Up', 'หน้าไม่อาย', 'Diamond In The Back', 'Onna Come Up', 'Fade Away', 'bad guy', 'Find Myself In You', 'Dia de Enero', 'Anything', 'Bussin', 'Posters', 'Eleven Years of Song a Day', 'Savoy Blues', 'BYE ME FUI', 'Josephine - New Recording', 'Hard Work Pays Off', 'A Walk Through Hell', 'Oh You Crazy Boy! - 2004 Remaster', 'More Than A Woman (feat. Calvin) - Duet w/ Calvin', 'T.G.I.F.', 'all the good girls go to hell', 'Stargirl Interlude', 'De Cora <3', 'Who Built the Moon', '2000 Year Old Nigun']

# %% [markdown]
# ## 5.5 Song Recommender Conclusion
#
# Using the cosine similarity matrix, we were able to build playlists of songs whose musical features were the most similar to the genres selected (Top 30 genres in this case). Upon further inspection of the playlists, we note that the songs recommended may not necessarily have been of the same genre, despite having similar musical features. For example, Katy Perry's track "Last Friday Night" is clearly a pop song, yet it was recommended in the Scandanavian R&B playlist, or how Eminem's rap hit "Sing For The moment" was considered similar to the Swedish Tropical House genre.
#
# This leads us to conclude that although songs may be categorised in a particular genre, their musical features could be similar to songs of another genre.
#
# In general, the playlists that generated the most similar songs tended tp be from the pop genres. For example, in the Mexican Pop Punk playlist, close to 50% of the songs could be classified as pop, despite being part of other genres as well. <a href="https://carrieunderwood.fandom.com/wiki/Country_Music">Carrie Underwood</a> and <a href="https://www.allmusic.com/artist/sam-hunt-mn0002674420/biography">Sam Hunt</a> and <a href="https://theboot.com/top-sara-evans-songs/">Sara Evans</a> typically associated with country music yet their music is generally defined as country pop.
#
# Overall, we see that the evolution of music has blurred the lines between the genres of music, meaning that songs traditionally classified as pop could also fall under indie - creating the subgenre Indie Pop. We can also point towards playlists such as Indonesian R&B which consists of mostly English songs but also contains Thai and Korean songs! From this, we see that musical features are language-agnostic and it is possible to be recommended songs which may not necessarily be from that genre, but they have similar musical features to that genre.
#
# In conclusion, music is fluid where genres transcend languages and music transcends the genres that define them. While recommending music similar to one genre, we may inadvertently recommend songs whose features are similar to other genres.
